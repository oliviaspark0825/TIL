# %% [markdown]
# # 가상화폐 시세 판단하기

# %% [markdown]
# > 최고가와 최저가의 차이를 변동폭으로 정의할 때 (시가 + 변동폭)이 최고가 보다 높을 경우 "상승장", 그렇지 않은 경우 "하락장" 문자열을 출력하라.
#
# |Key Name        |     Description|
# |---|---|
# |opening_price    |최근 24시간 내 시작 거래금액|
# |closing_price   |최근 24시간 내 마지막 거래금액|
# |min_price       |최근 24시간 내 최저 거래금액|
# |max_price       |최근 24시간 내 최고 거래금액|

# %%
import requests
from pprint import pprint
btc = requests.get('https://api.bithumb.com/public/ticker/btc').json()['data']
pprint(btc)
# Out:
# {'24H_fluctate': '-26000',
#  '24H_fluctate_rate': '-0.60',
#  'average_price': '4301841.2743',
#  'buy_price': '4284000',
#  'closing_price': '4284000',
#  'date': '1546566510623',
#  'max_price': '4339000',
#  'min_price': '4250000',
#  'opening_price': '4310000',
#  'sell_price': '4286000',
#  'units_traded': '18085.46744689',
#  'volume_1day': '18085.46744689',
#  'volume_7day': '56322.07366253'}

# %%
# 아래에 코드를 작성하세요.

dif = float(btc['opening_price'])+ float(btc['max_price'])-float(btc['min_price'])

if dif > int(btc['max_price']):
    print(' 상승장')
else:
    print('하락장')
    
# ans

bdp = float(btc['max_price']) - float(btc['min_price'])
if int(btc['opening_price']) + bdp > int(btc['max_price']):
        print("상승장")
else:
    print('하락장')
# Out:
#  상승장
#  상승장

# %% [markdown]
# ## 모든 가상화폐 시세 판단하기
#
#
# > currrency dictionary에 담겨있는 모든 가상화폐 거래내역을 바탕으로 출력하라.
# >
# > 예외 처리에 유의하세요.
#
#
#
# ```
# 예시 출력)
# BTC 상승장
# ETH 상승장
# DASH 상승장
# LTC 하락장
# ETC 하락장
# XRP 상승장
# BCH 상승장
# ...
# ```

# %%
currency = requests.get('https://api.bithumb.com/public/ticker/all').json()['data']
pprint(currency)
# Out:
# {'ABT': {'24H_fluctate': '-3.9',
#          '24H_fluctate_rate': '-3.90',
#          'average_price': '103.2994',
#          'buy_price': '96.1',
#          'closing_price': '96.1',
#          'max_price': '115',
#          'min_price': '94.1',
#          'opening_price': '100',
#          'sell_price': '96.8',
#          'units_traded': '11521611.28591732',
#          'volume_1day': '11521611.28591732',
#          'volume_7day': '50380254.669295697921657788'},
#  'ADA': {'24H_fluctate': '-2.1',
#          '24H_fluctate_rate': '-2.67',
#          'average_price': '77.2282',
#          'buy_price': '75.7',
#          'closing_price': '76.4',
#          'max_price': '79.3',
#          'min_price': '75.1',
#          'opening_price': '78.5',
#          'sell_price': '76.4',
#          'units_traded': '2111462.0796801',
#          'volume_1day': '2111462.0796801',
#          'volume_7day': '39829301.35566205'},
#  'ADD': [],
#  'AE': {'24H_fluctate': '-31',
#         '24H_fluctate_rate': '-1.89',
#         'average_price': '1632.8657',
#         'buy_price': '1602',
#         'closing_price': '1602',
#         'max_price': '1678',
#         'min_price': '1600',
#         'opening_price': '1633',
#         'sell_price': '1621',
#         'units_traded': '67148.21845548',
#         'volume_1day': '67148.21845548',
#         'volume_7day': '1901660.58296807896023566'},
#  'AMO': {'24H_fluctate': '-0.18',
#          '24H_fluctate_rate': '-10.11',
#          'average_price': '1.6999',
#          'buy_price': '1.59',
#          'closing_price': '1.6',
#          'max_price': '1.78',
#          'min_price': '1.56',
#          'opening_price': '1.78',
#          'sell_price': '1.6',
#          'units_traded': '727725212.74126406',
#          'volume_1day': '727725212.74126406',
#          'volume_7day': '24099569711.125327148728050134'},
#  'BAT': {'24H_fluctate': '-4',
#          '24H_fluctate_rate': '-2.66',
#          'average_price': '147.1734',
#          'buy_price': '146',
#          'closing_price': '146',
#          'max_price': '154',
#          'min_price': '144',
#          'opening_price': '150',
#          'sell_price': '148',
#          'units_traded': '1532252.19096719',
#          'volume_1day': '1532252.19096719',
#          'volume_7day': '7026678.053205260973386136'},
#  'BCD': {'24H_fluctate': '-30',
#          '24H_fluctate_rate': '-2.89',
#          'average_price': '1017.1774',
#          'buy_price': '1002',
#          'closing_price': '1007',
#          'max_price': '1040',
#          'min_price': '997',
#          'opening_price': '1037',
#          'sell_price': '1007',
#          'units_traded': '114140.91638184',
#          'volume_1day': '114140.91638184',
#          'volume_7day': '1808615.62850526'},
#  'BCH': {'24H_fluctate': '-10400',
#          '24H_fluctate_rate': '-5.41',
#          'average_price': '184073.8577',
#          'buy_price': '181500',
#          'closing_price': '181600',
#          'max_price': '192700',
#          'min_price': '177300',
#          'opening_price': '192000',
#          'sell_price': '181900',
#          'units_traded': '47898.67506711',
#          'volume_1day': '47898.67506711',
#          'volume_7day': '555197.59040617'},
#  'BHPC': {'24H_fluctate': '-1',
#           '24H_fluctate_rate': '-0.11',
#           'average_price': '910.2302',
#           'buy_price': '902',
#           'closing_price': '905',
#           'max_price': '927',
#           'min_price': '890',
#           'opening_price': '906',
#           'sell_price': '905',
#           'units_traded': '451102.19675765',
#           'volume_1day': '451102.19675765',
#           'volume_7day': '8371169.073761527652769304'},
#  'BLACK': [],
#  'BSV': {'24H_fluctate': '-3700',
#          '24H_fluctate_rate': '-3.57',
#          'average_price': '100556.7225',
#          'buy_price': '99800',
#          'closing_price': '99800',
#          'max_price': '104400',
#          'min_price': '97400',
#          'opening_price': '103500',
#          'sell_price': '100000',
#          'units_traded': '23988.11189732',
#          'volume_1day': '23988.11189732',
#          'volume_7day': '270185.40634518'},
#  'BTC': {'24H_fluctate': '-40000',
#          '24H_fluctate_rate': '-0.92',
#          'average_price': '4301592.8561',
#          'buy_price': '4277000',
#          'closing_price': '4277000',
#          'max_price': '4339000',
#          'min_price': '4250000',
#          'opening_price': '4317000',
#          'sell_price': '4281000',
#          'units_traded': '18073.31428032',
#          'volume_1day': '18073.31428032',
#          'volume_7day': '56272.97174155'},
#  'BTG': {'24H_fluctate': '-490',
#          '24H_fluctate_rate': '-3.28',
#          'average_price': '14526.1026',
#          'buy_price': '14390',
#          'closing_price': '14410',
#          'max_price': '15040',
#          'min_price': '12970',
#          'opening_price': '14900',
#          'sell_price': '14410',
#          'units_traded': '22441205.69594494',
#          'volume_1day': '22441205.69594494',
#          'volume_7day': '98513485.57345587'},
#  'BZNT': {'24H_fluctate': '-0.09',
#           '24H_fluctate_rate': '-0.35',
#           'average_price': '27.9409',
#           'buy_price': '27.8',
#           'closing_price': '27.8',
#           'max_price': '29.3',
#           'min_price': '27',
#           'opening_price': '27.9',
#           'sell_price': '27.9',
#           'units_traded': '35370551.00304837',
#           'volume_1day': '35370551.00304837',
#           'volume_7day': '191533708.244233452831885565'},
#  'CHL': [],
#  'CMT': {'24H_fluctate': '-0.7',
#          '24H_fluctate_rate': '-1.98',
#          'average_price': '34.5889',
#          'buy_price': '34.6',
#          'closing_price': '34.6',
#          'max_price': '36.2',
#          'min_price': '32.4',
#          'opening_price': '35.3',
#          'sell_price': '34.7',
#          'units_traded': '4818055.87345042',
#          'volume_1day': '4818055.87345042',
#          'volume_7day': '36608959.691895702860476475'},
#  'CTXC': {'24H_fluctate': '-4',
#           '24H_fluctate_rate': '-3.33',
#           'average_price': '118.1146',
#           'buy_price': '115',
#           'closing_price': '116',
#           'max_price': '124',
#           'min_price': '113',
#           'opening_price': '120',
#           'sell_price': '117',
#           'units_traded': '1353029.80551294',
#           'volume_1day': '1353029.80551294',
#           'volume_7day': '11516044.224321014673753123'},
#  'DASH': {'24H_fluctate': '-2900',
#           '24H_fluctate_rate': '-3.10',
#           'average_price': '90928.4474',
#           'buy_price': '90400',
#           'closing_price': '90600',
#           'max_price': '93800',
#           'min_price': '88100',
#           'opening_price': '93500',
#           'sell_price': '90700',
#           'units_traded': '3950691.78253308',
#           'volume_1day': '3950691.78253308',
#           'volume_7day': '32141973.13682674'},
#  'ELF': {'24H_fluctate': '7',
#          '24H_fluctate_rate': '5.46',
#          'average_price': '132.1769',
#          'buy_price': '134',
#          'closing_price': '135',
#          'max_price': '139',
#          'min_price': '125',
#          'opening_price': '128',
#          'sell_price': '135',
#          'units_traded': '5087475.50210202',
#          'volume_1day': '5087475.50210202',
#          'volume_7day': '18483619.311288335405889591'},
#  'ENJ': {'24H_fluctate': '-1.6',
#          '24H_fluctate_rate': '-3.57',
#          'average_price': '44.0417',
#          'buy_price': '43.2',
#          'closing_price': '43.2',
#          'max_price': '45.7',
#          'min_price': '42.6',
#          'opening_price': '44.8',
#          'sell_price': '43.5',
#          'units_traded': '3477823.53158923',
#          'volume_1day': '3477823.53158923',
#          'volume_7day': '23052201.634158192816118614'},
#  'EOS': {'24H_fluctate': '-128',
#          '24H_fluctate_rate': '-4.09',
#          'average_price': '3047.3651',
#          'buy_price': '2996',
#          'closing_price': '3000',
#          'max_price': '3166',
#          'min_price': '2930',
#          'opening_price': '3128',
#          'sell_price': '3000',
#          'units_traded': '2415023.63742813',
#          'volume_1day': '2415023.63742813',
#          'volume_7day': '22788094.55356183'},
#  'EOSDAC': [],
#  'ETC': {'24H_fluctate': '-265',
#          '24H_fluctate_rate': '-4.45',
#          'average_price': '5781.5086',
#          'buy_price': '5685',
#          'closing_price': '5685',
#          'max_price': '5995',
#          'min_price': '5640',
#          'opening_price': '5950',
#          'sell_price': '5700',
#          'units_traded': '527685.52539124',
#          'volume_1day': '527685.52539124',
#          'volume_7day': '1873490.196914439873039507'},
#  'ETH': {'24H_fluctate': '-2700',
#          '24H_fluctate_rate': '-1.58',
#          'average_price': '168181.9186',
#          'buy_price': '167500',
#          'closing_price': '167500',
#          'max_price': '173800',
#          'min_price': '163500',
#          'opening_price': '170200',
#          'sell_price': '167600',
#          'units_traded': '581280.84534694',
#          'volume_1day': '581280.84534694',
#          'volume_7day': '1971329.512007973008176219'},
#  'ETHOS': {'24H_fluctate': '-11',
#            '24H_fluctate_rate': '-0.99',
#            'average_price': '1107.8531',
#            'buy_price': '1089',
#            'closing_price': '1095',
#            'max_price': '1177',
#            'min_price': '1050',
#            'opening_price': '1106',
#            'sell_price': '1095',
#            'units_traded': '256550.45917046',
#            'volume_1day': '256550.45917046',
#            'volume_7day': '6312720.00446809'},
#  'GNT': {'24H_fluctate': '-0.7',
#          '24H_fluctate_rate': '-0.90',
#          'average_price': '76.5394',
#          'buy_price': '75.5',
#          'closing_price': '76.3',
#          'max_price': '78.5',
#          'min_price': '75.3',
#          'opening_price': '77',
#          'sell_price': '76.2',
#          'units_traded': '1065704.82459068',
#          'volume_1day': '1065704.82459068',
#          'volume_7day': '37311327.099545753986240579'},
#  'GTO': {'24H_fluctate': '-0.89',
#          '24H_fluctate_rate': '-1.23',
#          'average_price': '74.1381',
#          'buy_price': '72.2',
#          'closing_price': '72.2',
#          'max_price': '78.1',
#          'min_price': '71.2',
#          'opening_price': '73.1',
#          'sell_price': '73',
#          'units_traded': '2166086.82322207',
#          'volume_1day': '2166086.82322207',
#          'volume_7day': '24930166.17785879'},
#  'HC': {'24H_fluctate': '-4',
#         '24H_fluctate_rate': '-0.27',
#         'average_price': '1444.6351',
#         'buy_price': '1411',
#         'closing_price': '1426',
#         'max_price': '1512',
#         'min_price': '1380',
#         'opening_price': '1430',
#         'sell_price': '1426',
#         'units_traded': '82147.83733315',
#         'volume_1day': '82147.83733315',
#         'volume_7day': '888283.17960032'},
#  'HORUS': [],
#  'ICX': {'24H_fluctate': '2',
#          '24H_fluctate_rate': '0.68',
#          'average_price': '294.8896',
#          'buy_price': '292',
#          'closing_price': '292',
#          'max_price': '318',
#          'min_price': '281',
#          'opening_price': '290',
#          'sell_price': '294',
#          'units_traded': '2093080.79556089',
#          'volume_1day': '2093080.79556089',
#          'volume_7day': '5012731.551027308297395376'},
#  'INS': {'24H_fluctate': '17',
#          '24H_fluctate_rate': '5.12',
#          'average_price': '339.1906',
#          'buy_price': '349',
#          'closing_price': '349',
#          'max_price': '366',
#          'min_price': '316',
#          'opening_price': '332',
#          'sell_price': '351',
#          'units_traded': '4396763.9066279',
#          'volume_1day': '4396763.9066279',
#          'volume_7day': '11843464.9704243662'},
#  'IOST': {'24H_fluctate': '-0.06',
#           '24H_fluctate_rate': '-0.93',
#           'average_price': '6.3326',
#           'buy_price': '6.28',
#           'closing_price': '6.38',
#           'max_price': '6.52',
#           'min_price': '6.16',
#           'opening_price': '6.44',
#           'sell_price': '6.36',
#           'units_traded': '423008565.34388327',
#           'volume_1day': '423008565.34388327',
#           'volume_7day': '1446126677.099736040869225289'},
#  'ITC': {'24H_fluctate': '-3',
#          '24H_fluctate_rate': '-2.14',
#          'average_price': '136.7199',
#          'buy_price': '136',
#          'closing_price': '137',
#          'max_price': '141',
#          'min_price': '133',
#          'opening_price': '140',
#          'sell_price': '137',
#          'units_traded': '1468878.15434434',
#          'volume_1day': '1468878.15434434',
#          'volume_7day': '17820258.614070639705758781'},
#  'KNC': {'24H_fluctate': '-8',
#          '24H_fluctate_rate': '-4.34',
#          'average_price': '179.6701',
#          'buy_price': '176',
#          'closing_price': '176',
#          'max_price': '185',
#          'min_price': '173',
#          'opening_price': '184',
#          'sell_price': '177',
#          'units_traded': '843637.98255387',
#          'volume_1day': '843637.98255387',
#          'volume_7day': '7214318.672790646089975132'},
#  'LINK': {'24H_fluctate': '37',
#           '24H_fluctate_rate': '9.73',
#           'average_price': '402.4231',
#           'buy_price': '416',
#           'closing_price': '417',
#           'max_price': '446',
#           'min_price': '358',
#           'opening_price': '380',
#           'sell_price': '417',
#           'units_traded': '12659886.0633349',
#           'volume_1day': '12659886.0633349',
#           'volume_7day': '16476890.250821760475708323'},
#  'LOOM': {'24H_fluctate': '-1.4',
#           '24H_fluctate_rate': '-2.48',
#           'average_price': '57.6574',
#           'buy_price': '54.3',
#           'closing_price': '55',
#           'max_price': '63.8',
#           'min_price': '53.1',
#           'opening_price': '56.4',
#           'sell_price': '54.9',
#           'units_traded': '23922899.87196854',
#           'volume_1day': '23922899.87196854',
#           'volume_7day': '47073888.889544511561186799'},
#  'LRC': {'24H_fluctate': '-27',
#          '24H_fluctate_rate': '-4.57',
#          'average_price': '577.722',
#          'buy_price': '563',
#          'closing_price': '563',
#          'max_price': '595',
#          'min_price': '563',
#          'opening_price': '590',
#          'sell_price': '569',
#          'units_traded': '131906.23658059',
#          'volume_1day': '131906.23658059',
#          'volume_7day': '2928033.480571617643527395'},
#  'LTC': {'24H_fluctate': '-750',
#          '24H_fluctate_rate': '-2.05',
#          'average_price': '35948.5025',
#          'buy_price': '35700',
#          'closing_price': '35800',
#          'max_price': '36920',
#          'min_price': '34940',
#          'opening_price': '36550',
#          'sell_price': '35800',
#          'units_traded': '12469.44119976',
#          'volume_1day': '12469.44119976',
#          'volume_7day': '176075.55492017'},
#  'MCO': {'24H_fluctate': '3',
#          '24H_fluctate_rate': '0.11',
#          'average_price': '2584.9886',
#          'buy_price': '2595',
#          'closing_price': '2622',
#          'max_price': '2645',
#          'min_price': '2533',
#          'opening_price': '2619',
#          'sell_price': '2623',
#          'units_traded': '804482.76880361',
#          'volume_1day': '804482.76880361',
#          'volume_7day': '1917843.15067829'},
#  'MEETONE': [],
#  'MITH': {'24H_fluctate': '-1.8',
#           '24H_fluctate_rate': '-2.53',
#           'average_price': '69.8751',
#           'buy_price': '69',
#           'closing_price': '69.3',
#           'max_price': '71.4',
#           'min_price': '68.3',
#           'opening_price': '71.1',
#           'sell_price': '69.3',
#           'units_traded': '9403714.84520668',
#           'volume_1day': '9403714.84520668',
#           'volume_7day': '107193907.38960550599621313'},
#  'OCN': {'24H_fluctate': '-0.22',
#          '24H_fluctate_rate': '-5.50',
#          'average_price': '3.8507',
#          'buy_price': '3.78',
#          'closing_price': '3.78',
#          'max_price': '4.05',
#          'min_price': '3.67',
#          'opening_price': '4',
#          'sell_price': '3.79',
#          'units_traded': '55683065.56548849',
#          'volume_1day': '55683065.56548849',
#          'volume_7day': '1604334484.314913560050201454'},
#  'OMG': {'24H_fluctate': '-4',
#          '24H_fluctate_rate': '-0.24',
#          'average_price': '1647.6737',
#          'buy_price': '1643',
#          'closing_price': '1656',
#          'max_price': '1691',
#          'min_price': '1612',
#          'opening_price': '1660',
#          'sell_price': '1656',
#          'units_traded': '1248631.27073158',
#          'volume_1day': '1248631.27073158',
#          'volume_7day': '10926681.587721818906013623'},
#  'PAY': {'24H_fluctate': '-51',
#          '24H_fluctate_rate': '-2.83',
#          'average_price': '1789.0868',
#          'buy_price': '1750',
#          'closing_price': '1750',
#          'max_price': '1845',
#          'min_price': '1730',
#          'opening_price': '1801',
#          'sell_price': '1760',
#          'units_traded': '195730.74530496',
#          'volume_1day': '195730.74530496',
#          'volume_7day': '8428339.501725144795132158'},
#  'PIVX': {'24H_fluctate': '-36',
#           '24H_fluctate_rate': '-3.74',
#           'average_price': '940.0792',
#           'buy_price': '916',
#           'closing_price': '925',
#           'max_price': '973',
#           'min_price': '914',
#           'opening_price': '961',
#           'sell_price': '926',
#           'units_traded': '157802.76920544',
#           'volume_1day': '157802.76920544',
#           'volume_7day': '10440404.93744645'},
#  'PLY': {'24H_fluctate': '-0.5',
#          '24H_fluctate_rate': '-1.30',
#          'average_price': '38.178',
#          'buy_price': '37.6',
#          'closing_price': '37.7',
#          'max_price': '40',
#          'min_price': '36.4',
#          'opening_price': '38.2',
#          'sell_price': '37.7',
#          'units_traded': '10198568.6013848',
#          'volume_1day': '10198568.6013848',
#          'volume_7day': '108836669.557638524'},
#  'POLY': {'24H_fluctate': '-3',
#           '24H_fluctate_rate': '-1.86',
#           'average_price': '157.4551',
#           'buy_price': '156',
#           'closing_price': '158',
#           'max_price': '162',
#           'min_price': '155',
#           'opening_price': '161',
#           'sell_price': '158',
#           'units_traded': '1213421.33049114',
#           'volume_1day': '1213421.33049114',
#           'volume_7day': '9984112.854597255355654461'},
#  'POWR': {'24H_fluctate': '-22',
#           '24H_fluctate_rate': '-4.08',
#           'average_price': '529.1245',
#           'buy_price': '514',
#           'closing_price': '516',
#           'max_price': '545',
#           'min_price': '512',
#           'opening_price': '538',
#           'sell_price': '516',
#           'units_traded': '419482.45892986',
#           'volume_1day': '419482.45892986',
#           'volume_7day': '6127683.26698003'},
#  'PPT': {'24H_fluctate': '-10',
#          '24H_fluctate_rate': '-0.59',
#          'average_price': '1663.2205',
#          'buy_price': '1653',
#          'closing_price': '1670',
#          'max_price': '1691',
#          'min_price': '1621',
#          'opening_price': '1680',
#          'sell_price': '1670',
#          'units_traded': '36687.2591',
#          'volume_1day': '36687.2591',
#          'volume_7day': '689828.48186665'},
#  'PST': {'24H_fluctate': '-3',
#          '24H_fluctate_rate': '-2.65',
#          'average_price': '111.5598',
#          'buy_price': '109',
#          'closing_price': '110',
#          'max_price': '117',
#          'min_price': '107',
#          'opening_price': '113',
#          'sell_price': '111',
#          'units_traded': '800099.89976885',
#          'volume_1day': '800099.89976885',
#          'volume_7day': '9443862.751911780616582618'},
#  'QTUM': {'24H_fluctate': '-73',
#           '24H_fluctate_rate': '-2.84',
#           'average_price': '2495.4137',
#           'buy_price': '2487',
#           'closing_price': '2491',
#           'max_price': '2567',
#           'min_price': '2449',
#           'opening_price': '2564',
#           'sell_price': '2495',
#           'units_traded': '676348.78363422',
#           'volume_1day': '676348.78363422',
#           'volume_7day': '2945822.3250343'},
#  'RDN': {'24H_fluctate': '-36',
#          '24H_fluctate_rate': '-10.81',
#          'average_price': '312.1047',
#          'buy_price': '294',
#          'closing_price': '297',
#          'max_price': '345',
#          'min_price': '279',
#          'opening_price': '333',
#          'sell_price': '296',
#          'units_traded': '7306982.95666833',
#          'volume_1day': '7306982.95666833',
#          'volume_7day': '25478872.079642721353021321'},
#  'REP': {'24H_fluctate': '-1850',
#          '24H_fluctate_rate': '-1.88',
#          'average_price': '96924.4883',
#          'buy_price': '95300',
#          'closing_price': '96250',
#          'max_price': '99300',
#          'min_price': '94800',
#          'opening_price': '98100',
#          'sell_price': '96200',
#          'units_traded': '3749.14903329',
#          'volume_1day': '3749.14903329',
#          'volume_7day': '94398.857148120518075148'},
#  'RNT': {'24H_fluctate': '7',
#          '24H_fluctate_rate': '5.10',
#          'average_price': '145.6084',
#          'buy_price': '144',
#          'closing_price': '144',
#          'max_price': '183',
#          'min_price': '116',
#          'opening_price': '137',
#          'sell_price': '145',
#          'units_traded': '81695276.04677549',
#          'volume_1day': '81695276.04677549',
#          'volume_7day': '183927133.406557193888509696'},
#  'ROM': {'24H_fluctate': '0.01',
#          '24H_fluctate_rate': '8.33',
#          'average_price': '0.1264',
#          'buy_price': '0.12',
#          'closing_price': '0.13',
#          'max_price': '0.13',
#          'min_price': '0.12',
#          'opening_price': '0.12',
#          'sell_price': '0.13',
#          'units_traded': '42434438575.70164615',
#          'volume_1day': '42434438575.70164615',
#          'volume_7day': '216834311406.565481660303161222'},
#  'SALT': {'24H_fluctate': '-19',
#           '24H_fluctate_rate': '-6.73',
#           'average_price': '274.3493',
#           'buy_price': '263',
#           'closing_price': '263',
#           'max_price': '289',
#           'min_price': '262',
#           'opening_price': '282',
#           'sell_price': '266',
#           'units_traded': '1542731.05845762',
#           'volume_1day': '1542731.05845762',
#           'volume_7day': '12803087.39722145'},
#  'SNT': {'24H_fluctate': '1',
#          '24H_fluctate_rate': '0.86',
#          'average_price': '116.472',
#          'buy_price': '115',
#          'closing_price': '116',
#          'max_price': '120',
#          'min_price': '112',
#          'opening_price': '115',
#          'sell_price': '116',
#          'units_traded': '1716854.10678952',
#          'volume_1day': '1716854.10678952',
#          'volume_7day': '24386765.772611629713343892'},
#  'STEEM': {'24H_fluctate': '-4',
#            '24H_fluctate_rate': '-0.21',
#            'average_price': '1825.3972',
#            'buy_price': '1804',
#            'closing_price': '1837',
#            'max_price': '1875',
#            'min_price': '1784',
#            'opening_price': '1841',
#            'sell_price': '1838',
#            'units_traded': '75570.6620933',
#            'volume_1day': '75570.6620933',
#            'volume_7day': '1365981.1535473'},
#  'STRAT': {'24H_fluctate': '-1',
#            '24H_fluctate_rate': '-0.03',
#            'average_price': '2843.5027',
#            'buy_price': '2805',
#            'closing_price': '2884',
#            'max_price': '2919',
#            'min_price': '2751',
#            'opening_price': '2885',
#            'sell_price': '2884',
#            'units_traded': '24883.65695097',
#            'volume_1day': '24883.65695097',
#            'volume_7day': '491312.1239285'},
#  'THETA': {'24H_fluctate': '-0.7',
#            '24H_fluctate_rate': '-1.22',
#            'average_price': '58.0194',
#            'buy_price': '56.3',
#            'closing_price': '56.4',
#            'max_price': '62.8',
#            'min_price': '55.4',
#            'opening_price': '57.1',
#            'sell_price': '56.4',
#            'units_traded': '17972006.1225032',
#            'volume_1day': '17972006.1225032',
#            'volume_7day': '92747031.877252723980381096'},
#  'TMTG': {'24H_fluctate': '-0.24',
#           '24H_fluctate_rate': '-2.86',
#           'average_price': '8.252',
#           'buy_price': '8.13',
#           'closing_price': '8.14',
#           'max_price': '8.41',
#           'min_price': '8.09',
#           'opening_price': '8.38',
#           'sell_price': '8.15',
#           'units_traded': '203285139.96619432',
#           'volume_1day': '203285139.96619432',
#           'volume_7day': '1486223079.862187940161481648'},
#  'TRUE': {'24H_fluctate': '34',
#           '24H_fluctate_rate': '11.64',
#           'average_price': '305.8481',
#           'buy_price': '318',
#           'closing_price': '326',
#           'max_price': '337',
#           'min_price': '287',
#           'opening_price': '292',
#           'sell_price': '325',
#           'units_traded': '2096387.57525577',
#           'volume_1day': '2096387.57525577',
#           'volume_7day': '8371064.996013637773447992'},
#  'TRX': {'24H_fluctate': '0.6',
#          '24H_fluctate_rate': '2.73',
#          'average_price': '22.4308',
#          'buy_price': '22.4',
#          'closing_price': '22.5',
#          'max_price': '23.2',
#          'min_price': '21.8',
#          'opening_price': '21.9',
#          'sell_price': '22.5',
#          'units_traded': '221977268.35091496',
#          'volume_1day': '221977268.35091496',
#          'volume_7day': '945422726.0394994'},
#  'VET': {'24H_fluctate': '-0.15',
#          '24H_fluctate_rate': '-2.06',
#          'average_price': '7.2008',
#          'buy_price': '7.1',
#          'closing_price': '7.1',
#          'max_price': '7.35',
#          'min_price': '7.09',
#          'opening_price': '7.25',
#          'sell_price': '7.13',
#          'units_traded': '7803683.77698701',
#          'volume_1day': '7803683.77698701',
#          'volume_7day': '72321314.03276151956123794'},
#  'WAVES': {'24H_fluctate': '0',
#            '24H_fluctate_rate': '0.00',
#            'average_price': '3484.1071',
#            'buy_price': '3444',
#            'closing_price': '3458',
#            'max_price': '3550',
#            'min_price': '3419',
#            'opening_price': '3458',
#            'sell_price': '3468',
#            'units_traded': '174280.47991167',
#            'volume_1day': '174280.47991167',
#            'volume_7day': '2678159.83460588'},
#  'WAX': {'24H_fluctate': '-4',
#          '24H_fluctate_rate': '-3.70',
#          'average_price': '105.6532',
#          'buy_price': '104',
#          'closing_price': '104',
#          'max_price': '108',
#          'min_price': '104',
#          'opening_price': '108',
#          'sell_price': '105',
#          'units_traded': '846199.64519347',
#          'volume_1day': '846199.64519347',
#          'volume_7day': '18107503.19963879'},
#  'WET': {'24H_fluctate': '-0.2',
#          '24H_fluctate_rate': '-1.40',
#          'average_price': '14.0808',
#          'buy_price': '13.9',
#          'closing_price': '14',
#          'max_price': '14.4',
#          'min_price': '13.9',
#          'opening_price': '14.2',
#          'sell_price': '14',
#          'units_traded': '18616502.81774204',
#          'volume_1day': '18616502.81774204',
#          'volume_7day': '195781954.289909116950969508'},
#  'WTC': {'24H_fluctate': '15',
#          '24H_fluctate_rate': '1.18',
#          'average_price': '1285.9565',
#          'buy_price': '1268',
#          'closing_price': '1282',
#          'max_price': '1328',
#          'min_price': '1253',
#          'opening_price': '1267',
#          'sell_price': '1282',
#          'units_traded': '228615.00387532',
#          'volume_1day': '228615.00387532',
#          'volume_7day': '2371659.744104949026476302'},
#  'XEM': {'24H_fluctate': '-1',
#          '24H_fluctate_rate': '-1.36',
#          'average_price': '73.2274',
#          'buy_price': '72.3',
#          'closing_price': '72.3',
#          'max_price': '75.4',
#          'min_price': '72',
#          'opening_price': '73.3',
#          'sell_price': '72.8',
#          'units_traded': '2185898.42105356',
#          'volume_1day': '2185898.42105356',
#          'volume_7day': '21653180.23743651'},
#  'XLM': {'24H_fluctate': '-3',
#          '24H_fluctate_rate': '-2.30',
#          'average_price': '128.1748',
#          'buy_price': '126',
#          'closing_price': '127',
#          'max_price': '131',
#          'min_price': '126',
#          'opening_price': '130',
#          'sell_price': '127',
#          'units_traded': '4785754.14242867',
#          'volume_1day': '4785754.14242867',
#          'volume_7day': '47785760.49395804'},
#  'XMR': {'24H_fluctate': '-1150',
#          '24H_fluctate_rate': '-2.02',
#          'average_price': '56004.6765',
#          'buy_price': '55250',
#          'closing_price': '55700',
#          'max_price': '57500',
#          'min_price': '55000',
#          'opening_price': '56850',
#          'sell_price': '55950',
#          'units_traded': '12443171.69881319',
#          'volume_1day': '12443171.69881319',
#          'volume_7day': '67420234.945024596036'},
#  'XRP': {'24H_fluctate': '-9',
#          '24H_fluctate_rate': '-2.19',
#          'average_price': '404.1482',
#          'buy_price': '401',
#          'closing_price': '401',
#          'max_price': '413',
#          'min_price': '397',
#          'opening_price': '410',
#          'sell_price': '402',
#          'units_traded': '46604300.75272507',
#          'volume_1day': '46604300.75272507',
#          'volume_7day': '475296684.80779362'},
#  'XVG': {'24H_fluctate': '-0.06',
#          '24H_fluctate_rate': '-0.88',
#          'average_price': '7.8699',
#          'buy_price': '7.76',
#          'closing_price': '7.86',
#          'max_price': '8.04',
#          'min_price': '7.72',
#          'opening_price': '7.93',
#          'sell_price': '7.86',
#          'units_traded': '5886608.14982363',
#          'volume_1day': '5886608.14982363',
#          'volume_7day': '51452796.89438424'},
#  'ZEC': {'24H_fluctate': '-1600',
#          '24H_fluctate_rate': '-2.38',
#          'average_price': '65708.2914',
#          'buy_price': '65450',
#          'closing_price': '65500',
#          'max_price': '67350',
#          'min_price': '64150',
#          'opening_price': '67100',
#          'sell_price': '65500',
#          'units_traded': '35961.97224304',
#          'volume_1day': '35961.97224304',
#          'volume_7day': '33687660.42902229'},
#  'ZIL': {'24H_fluctate': '-0.4',
#          '24H_fluctate_rate': '-1.76',
#          'average_price': '22.3751',
#          'buy_price': '22.2',
#          'closing_price': '22.2',
#          'max_price': '22.7',
#          'min_price': '22',
#          'opening_price': '22.6',
#          'sell_price': '22.3',
#          'units_traded': '19768969.19658188',
#          'volume_1day': '19768969.19658188',
#          'volume_7day': '457211311.130613354635'},
#  'ZRX': {'24H_fluctate': '-1',
#          '24H_fluctate_rate': '-0.27',
#          'average_price': '363.8487',
#          'buy_price': '360',
#          'closing_price': '360',
#          'max_price': '370',
#          'min_price': '356',
#          'opening_price': '361',
#          'sell_price': '362',
#          'units_traded': '992709.19075099',
#          'volume_1day': '992709.19075099',
#          'volume_7day': '5922544.072481677377380573'},
#  'date': '1546567380941'}

# %%
# 아래에 코드를 작성하세요.
for value in currency.values():
    bdp_1 = float(value['opening_price'])+ float(value['max_price'])-float(value['min_price'])
    if bdp_1> float(value['max_price']):
        print("상승장")
    else:
        print("하락장")
# Out:
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# 상승장
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-a8b5128e22a6> in <module>
#       1 # 아래에 코드를 작성하세요.
#       2 for value in currency.values():
# ----> 3     bdp_1 = float(value['opening_price'])+ float(value['max_price'])-float(value['min_price'])
#       4     if bdp_1> float(value['max_price']):
#       5         print("상승장")
#
# TypeError: list indices must be integers or slices, not str

# %%
# 키가 ada 이고 나머지가 밸류, 근데 도중에 []
#=> 밸류값이 딕셔너리인 애들만 받기로하면 편함

# %%
for key, value in currency.items():
    if type(value) == type(dict()):
        bdp = float(value['max_price']) - float(value['min_price'])
        if float(value['opening_price']) + bdp > float(value['max_price']):
            print(f"{key:5}상승장")
        else:
            print(f"{key:5}하락장")
# Out:
# BTC  상승장
# ETH  상승장
# DASH 상승장
# LTC  상승장
# ETC  상승장
# XRP  상승장
# BCH  상승장
# XMR  상승장
# ZEC  상승장
# QTUM 상승장
# BTG  상승장
# EOS  상승장
# ICX  상승장
# VET  상승장
# TRX  상승장
# ELF  상승장
# MITH 상승장
# MCO  상승장
# OMG  상승장
# KNC  상승장
# GNT  상승장
# ZIL  상승장
# ETHOS상승장
# PAY  상승장
# WAX  상승장
# POWR 상승장
# LRC  상승장
# GTO  상승장
# STEEM상승장
# STRAT상승장
# ZRX  상승장
# REP  상승장
# AE   상승장
# XEM  상승장
# SNT  상승장
# ADA  상승장
# PPT  상승장
# CTXC 상승장
# CMT  상승장
# THETA상승장
# WTC  상승장
# ITC  상승장
# TRUE 상승장
# ABT  상승장
# RNT  상승장
# PLY  상승장
# WAVES상승장
# LINK 상승장
# ENJ  상승장
# PST  상승장
# SALT 상승장
# RDN  상승장
# LOOM 상승장
# BHPC 상승장
# PIVX 상승장
# INS  상승장
# BCD  상승장
# BZNT 상승장
# XLM  상승장
# OCN  상승장
# BSV  상승장
# TMTG 상승장
# BAT  상승장
# WET  상승장
# XVG  상승장
# IOST 상승장
# POLY 상승장
# HC   상승장
# ROM  하락장
# AMO  상승장
